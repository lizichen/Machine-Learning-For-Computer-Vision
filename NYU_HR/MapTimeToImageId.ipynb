# %%
import csv
from datetime import datetime

fps = 12 # 12 frames extracted from the source video per second
FMT = '%H:%M:%S'
CSV_TIME_LABELS_SRC = "TimeAndLabels_Light_ch01.csv"
IMAGENAME_LABELS_TARGET = 'Light_Ch01_Labels.csv'
Camera_Channel = "ch01" # image pre-fix

timestamp = []
label = []
with open(CSV_TIME_LABELS_SRC, "rb") as csvfile:
    reader = csv.reader(csvfile, delimiter=",")
    for i, line in enumerate(reader):
        timestamp.append(line[0])
        label.append(line[1])

i = len(timestamp)
timestamp.append(timestamp[i-1])

target = open(IMAGENAME_LABELS_TARGET, 'a+')
write_count = 1 # close and reopen after 8000

img_indexStart = 0
img_indexEnd = 1

for timeindex in range(0, i):
    currenttime = timestamp[timeindex]
    nexttime = timestamp[timeindex+1]
    currentlabel = label[timeindex]
    
    diff_sec = (datetime.strptime(nexttime, FMT) - datetime.strptime(currenttime, FMT)).seconds
    
    img_indexStart = img_indexEnd
    img_indexEnd = img_indexStart + diff_sec * fps
    
    print "Generating {Image_ID, Label} pairs from:"+str(img_indexStart)+" to:"+str(img_indexEnd-1)+" labeling:"+currentlabel
    for rep in range(img_indexStart, img_indexEnd):
        line = Camera_Channel+'{:06d}'.format(rep) + "," + currentlabel 
        target.write(line)
        target.write("\n")
    
    write_count += 1
    if write_count % 7000 == 0:
        target.close()
        target = open(IMAGENAME_LABELS_TARGET, 'a+')

target.close()
print "done."
# Out:
# Generating {Image_ID, Label} pairs from:1 to:300 labeling:N/A
# Generating {Image_ID, Label} pairs from:301 to:492 labeling:ZERO
# Generating {Image_ID, Label} pairs from:493 to:540 labeling:ONE
# Generating {Image_ID, Label} pairs from:541 to:684 labeling:TWO
# Generating {Image_ID, Label} pairs from:685 to:780 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:781 to:864 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:865 to:960 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:961 to:1056 labeling:FOUR
# Generating {Image_ID, Label} pairs from:1057 to:1140 labeling:FIVE
# Generating {Image_ID, Label} pairs from:1141 to:1224 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:1225 to:1320 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:1321 to:1380 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:1381 to:1452 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:1453 to:1548 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:1549 to:1608 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:1609 to:1692 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:1693 to:1752 labeling:FIVE
# Generating {Image_ID, Label} pairs from:1753 to:1836 labeling:FOUR
# Generating {Image_ID, Label} pairs from:1837 to:1908 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:1909 to:1992 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:1993 to:2076 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:2077 to:2196 labeling:TWO
# Generating {Image_ID, Label} pairs from:2197 to:2256 labeling:ONE
# Generating {Image_ID, Label} pairs from:2257 to:2316 labeling:ZERO
# Generating {Image_ID, Label} pairs from:2317 to:2472 labeling:N/A
# Generating {Image_ID, Label} pairs from:2473 to:2532 labeling:ZERO
# Generating {Image_ID, Label} pairs from:2533 to:2556 labeling:ONE
# Generating {Image_ID, Label} pairs from:2557 to:2616 labeling:TWO
# Generating {Image_ID, Label} pairs from:2617 to:2688 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:2689 to:2748 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:2749 to:2808 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:2809 to:2856 labeling:FOUR
# Generating {Image_ID, Label} pairs from:2857 to:2928 labeling:FIVE
# Generating {Image_ID, Label} pairs from:2929 to:2988 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:2989 to:3048 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:3049 to:3108 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:3109 to:3156 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:3157 to:3156 labeling:ZERO
# Generating {Image_ID, Label} pairs from:3157 to:3240 labeling:N/A
# Generating {Image_ID, Label} pairs from:3241 to:3264 labeling:ZERO
# Generating {Image_ID, Label} pairs from:3265 to:3288 labeling:ONE
# Generating {Image_ID, Label} pairs from:3289 to:3336 labeling:TWO
# Generating {Image_ID, Label} pairs from:3337 to:3408 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:3409 to:3444 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:3445 to:3504 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:3505 to:3564 labeling:FOUR
# Generating {Image_ID, Label} pairs from:3565 to:3612 labeling:FIVE
# Generating {Image_ID, Label} pairs from:3613 to:3660 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:3661 to:3708 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:3709 to:3768 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:3769 to:3816 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:3817 to:3888 labeling:N/A
# Generating {Image_ID, Label} pairs from:3889 to:3924 labeling:ZERO
# Generating {Image_ID, Label} pairs from:3925 to:3960 labeling:ONE
# Generating {Image_ID, Label} pairs from:3961 to:4008 labeling:TWO
# Generating {Image_ID, Label} pairs from:4009 to:4056 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:4057 to:4104 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:4105 to:4128 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:4129 to:4224 labeling:FOUR
# Generating {Image_ID, Label} pairs from:4225 to:4260 labeling:FIVE
# Generating {Image_ID, Label} pairs from:4261 to:4308 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:4309 to:4380 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:4381 to:4428 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:4429 to:4464 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:4465 to:4500 labeling:N/A
# Generating {Image_ID, Label} pairs from:4501 to:4560 labeling:ZERO
# Generating {Image_ID, Label} pairs from:4561 to:4584 labeling:ONE
# Generating {Image_ID, Label} pairs from:4585 to:4620 labeling:TWO
# Generating {Image_ID, Label} pairs from:4621 to:4668 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:4669 to:4704 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:4705 to:4728 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:4729 to:4764 labeling:FOUR
# Generating {Image_ID, Label} pairs from:4765 to:4812 labeling:FIVE
# Generating {Image_ID, Label} pairs from:4813 to:4860 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:4861 to:4884 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:4885 to:4932 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:4933 to:4944 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:4945 to:5100 labeling:N/A
# Generating {Image_ID, Label} pairs from:5101 to:5148 labeling:ZERO
# Generating {Image_ID, Label} pairs from:5149 to:5172 labeling:ONE
# Generating {Image_ID, Label} pairs from:5173 to:5196 labeling:TWO
# Generating {Image_ID, Label} pairs from:5197 to:5244 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:5245 to:5304 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:5305 to:5340 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:5341 to:5376 labeling:FOUR
# Generating {Image_ID, Label} pairs from:5377 to:5412 labeling:FIVE
# Generating {Image_ID, Label} pairs from:5413 to:5460 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:5461 to:5520 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:5521 to:5532 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:5533 to:5760 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:5761 to:5820 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:5821 to:5868 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:5869 to:5916 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:5917 to:5952 labeling:FIVE
# Generating {Image_ID, Label} pairs from:5953 to:6012 labeling:FOUR
# Generating {Image_ID, Label} pairs from:6013 to:6048 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:6049 to:6108 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:6109 to:6156 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:6157 to:6192 labeling:TWO
# Generating {Image_ID, Label} pairs from:6193 to:6240 labeling:ONE
# Generating {Image_ID, Label} pairs from:6241 to:6264 labeling:ZERO
# Generating {Image_ID, Label} pairs from:6265 to:6360 labeling:N/A
# Generating {Image_ID, Label} pairs from:6361 to:6384 labeling:ONE
# Generating {Image_ID, Label} pairs from:6385 to:6408 labeling:ZERO
# Generating {Image_ID, Label} pairs from:6409 to:6468 labeling:ONE
# Generating {Image_ID, Label} pairs from:6469 to:6540 labeling:TWO
# Generating {Image_ID, Label} pairs from:6541 to:6624 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:6625 to:6756 labeling:THREE(US)
# Generating {Image_ID, Label} pairs from:6757 to:6876 labeling:THREE(UK)
# Generating {Image_ID, Label} pairs from:6877 to:6960 labeling:FOUR
# Generating {Image_ID, Label} pairs from:6961 to:7032 labeling:FIVE
# Generating {Image_ID, Label} pairs from:7033 to:7176 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:7177 to:7272 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:7273 to:7356 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:7357 to:7452 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:7453 to:7488 labeling:N/A
# Generating {Image_ID, Label} pairs from:7489 to:7548 labeling:ONE
# Generating {Image_ID, Label} pairs from:7549 to:7608 labeling:TWO
# Generating {Image_ID, Label} pairs from:7609 to:7680 labeling:THREE(CN)
# Generating {Image_ID, Label} pairs from:7681 to:7776 labeling:FOUR
# Generating {Image_ID, Label} pairs from:7777 to:7848 labeling:FIVE
# Generating {Image_ID, Label} pairs from:7849 to:7944 labeling:SIX(CN)
# Generating {Image_ID, Label} pairs from:7945 to:8004 labeling:SEVEN(CN)
# Generating {Image_ID, Label} pairs from:8005 to:8076 labeling:EIGHT(CN)
# Generating {Image_ID, Label} pairs from:8077 to:8124 labeling:NINE(CN)
# Generating {Image_ID, Label} pairs from:8125 to:8148 labeling:ZERO
# Generating {Image_ID, Label} pairs from:8149 to:8688 labeling:N/A
# Generating {Image_ID, Label} pairs from:8689 to:8688 labeling:N/A
# done.
